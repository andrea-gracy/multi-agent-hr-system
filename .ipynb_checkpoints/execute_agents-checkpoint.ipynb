# %%
import crewai
print(crewai.__version__)
# Out:
# 1.15.1

# %%
# !python3 main.py
# Out:
# Traceback (most recent call last):
#   File "/Users/andreagracy/Documents/graded-assignments/Week 12_Graded Project_AndreaGracy/hr_support_system1/main.py", line 1, in <module>
#     from crew.crew import HRCrew
#   File "/Users/andreagracy/Documents/graded-assignments/Week 12_Graded Project_AndreaGracy/hr_support_system1/crew/crew.py", line 3, in <module>
#     from crewai import Crew, Process
# ModuleNotFoundError: No module named 'crewai'

# %%
import sys
print(sys.executable)
import crewai
print(crewai.__version__)
# Out:
# /Users/andreagracy/crewai_new_env/bin/python
# 1.15.1

# %%
# !which python3
# !python3 --version
# !python3 -m pip show crewai
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/bin/python3
# Python 3.11.9
# WARNING: Package(s) not found: crewai

# %%
import sys
# !{sys.executable} main.py
# Out:
# ================================================================================
# HR Employee Support System
# ================================================================================
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 89d19a8e-a44a-49f1-8590-eaf6075dabe7                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category                                                              │
# │     - Leave                                                                  │
# │     - Payroll                                                                │
# │     - Benefits                                                               │
# │     - Internal Transfer                                                      │
# │     - Grievance                                                              │
# │     - General HR                                                             │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency                                                                  │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  4. Sensitivity                                                              │
# │     - Sensitive                                                              │
# │     - Not Sensitive                                                          │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  ID: 971eea07-4ccc-44c3-a765-dffd67ac27a2                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Task:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category                                                              │
# │     - Leave                                                                  │
# │     - Payroll                                                                │
# │     - Benefits                                                               │
# │     - Internal Transfer                                                      │
# │     - Grievance                                                              │
# │     - General HR                                                             │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency                                                                  │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  4. Sensitivity                                                              │
# │     - Sensitive                                                              │
# │     - Not Sensitive                                                          │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Category: Leave                                                             │
# │  Intent: To know the remaining number of casual leaves available for the     │
# │  current year.                                                               │
# │  Urgency: Low                                                                │
# │  Sensitivity: Not Sensitive                                                  │
# │  Missing Information: Employee identification details or context (e.g.,      │
# │  employee ID or name) to access leave records.                               │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category                                                              │
# │     - Leave                                                                  │
# │     - Payroll                                                                │
# │     - Benefits                                                               │
# │     - Internal Transfer                                                      │
# │     - Grievance                                                              │
# │     - General HR                                                             │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency                                                                  │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  4. Sensitivity                                                              │
# │     - Sensitive                                                              │
# │     - Not Sensitive                                                          │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category\n   - Leave\n   - Payroll\n   - Benefits\n   -  │
# │  Internal Transfer\n   - Grievance\n   - General HR\n\n2. Employee           │
# │  Intent\n\n3. Urgency\n   - Low\n   - Medium\n   - High\n\n4. Sensitivity\n  │
# │  - Sensitive\n   - Not Sensitive\n\n5. Any missing information               │
# │  required.\n\nReturn the output in the following                             │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('971eea07-4ccc-44c3-a765-dffd67ac27a2') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │  - Leave                                                                     │
# │  - Payroll                                                                   │
# │  - Benefits                                                                  │
# │  - Internal Transfer                                                         │
# │  - Grievance                                                                 │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  ID: 4f7d2978-f4d6-4028-b91e-55f90cff798a                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category\n   - Leave\n   - Payroll\n   - Benefits\n   -  │
# │  Internal Transfer\n   - Grievance\n   - General HR\n\n2. Employee           │
# │  Intent\n\n3. Urgency\n   - Low\n   - Medium\n   - High\n\n4. Sensitivity\n  │
# │  - Sensitive\n   - Not Sensitive\n\n5. Any missing information               │
# │  required.\n\nReturn the output in the following                             │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('971eea07-4ccc-44c3-a765-dffd67ac27a2') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │  - Leave                                                                     │
# │  - Payroll                                                                   │
# │  - Benefits                                                                  │
# │  - Internal Transfer                                                         │
# │  - Grievance                                                                 │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Applicable Policy:                                                          │
# │  The applicable HR policy is the "Casual Leave Policy." Typically, casual    │
# │  leave is granted to employees for short-term absences due to personal or    │
# │  urgent matters. The policy defines the annual entitlement of casual leave   │
# │  days, the process for applying, approval workflows, and conditions under    │
# │  which casual leave can be carried forward or encashed (if any).             │
# │                                                                              │
# │  Eligibility:                                                                │
# │  Generally, all regular full-time employees are eligible for casual leave.   │
# │  Eligibility may vary based on employment type (e.g., full-time, part-time,  │
# │  contractual). Probationary employees usually accrue casual leave            │
# │  proportionally or may have certain restrictions. Without specific employee  │
# │  details, it is assumed the employee is eligible for casual leave as per     │
# │  standard eligibility criteria.                                              │
# │                                                                              │
# │  Explanation:                                                                │
# │  Casual leaves are granted annually as per company policy, and the           │
# │  entitlement resets every calendar or fiscal year. The employee’s remaining  │
# │  casual leave balance depends on leaves already taken during the current     │
# │  year. To determine the number of casual leave days remaining, the           │
# │  employee's leave records must be accessed in the HR or leave management     │
# │  system using the employee’s identification details. Since the employee has  │
# │  not provided identification information (such as employee ID or name), HR   │
# │  or the leave administrator cannot retrieve the exact balance. The urgency   │
# │  is low and the request is not sensitive.                                    │
# │                                                                              │
# │  Recommended Next Step:                                                      │
# │  Request the employee to provide their employee ID or full name to access    │
# │  the leave management system and check their casual leave balance.           │
# │  Alternatively, direct the employee to the self-service HR portal (if        │
# │  available), where they can log in securely and view their updated leave     │
# │  balances. Once identified, the HR team or automated system can provide an   │
# │  accurate count of remaining casual leaves for the current year.             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category\n   - Leave\n   - Payroll\n   - Benefits\n   -  │
# │  Internal Transfer\n   - Grievance\n   - General HR\n\n2. Employee           │
# │  Intent\n\n3. Urgency\n   - Low\n   - Medium\n   - High\n\n4. Sensitivity\n  │
# │  - Sensitive\n   - Not Sensitive\n\n5. Any missing information               │
# │  required.\n\nReturn the output in the following                             │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('971eea07-4ccc-44c3-a765-dffd67ac27a2') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │  - Leave                                                                     │
# │  - Payroll                                                                   │
# │  - Benefits                                                                  │
# │  - Internal Transfer                                                         │
# │  - Grievance                                                                 │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │  - Harassment                                                                │
# │  - Bullying                                                                  │
# │  - Discrimination                                                            │
# │  - Workplace misconduct                                                      │
# │  - Data privacy                                                              │
# │  - Confidential matters                                                      │
# │  - Legal issues                                                              │
# │  - Threats                                                                   │
# │  - Violence                                                                  │
# │  - Extremely urgent situations                                               │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  ID: 3690da35-691e-4c37-8cd3-8b1b6e337f02                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │  - Harassment                                                                │
# │  - Bullying                                                                  │
# │  - Discrimination                                                            │
# │  - Workplace misconduct                                                      │
# │  - Data privacy                                                              │
# │  - Confidential matters                                                      │
# │  - Legal issues                                                              │
# │  - Threats                                                                   │
# │  - Violence                                                                  │
# │  - Extremely urgent situations                                               │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Escalation Required: No                                                     │
# │  Priority: Low                                                               │
# │  Reason: The query is a routine request for information about the remaining  │
# │  casual leave balance for the current year. It does not involve any          │
# │  sensitive or confidential matters, harassment, discrimination, misconduct,  │
# │  legal issues, threats, or violence. The urgency is low. The appropriate     │
# │  action is to request the employee to provide their identification details   │
# │  or to use the self-service HR portal to obtain their leave balance. This    │
# │  matter can be handled through automated resolution without human HR         │
# │  intervention.                                                               │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │  - Harassment                                                                │
# │  - Bullying                                                                  │
# │  - Discrimination                                                            │
# │  - Workplace misconduct                                                      │
# │  - Data privacy                                                              │
# │  - Confidential matters                                                      │
# │  - Legal issues                                                              │
# │  - Threats                                                                   │
# │  - Violence                                                                  │
# │  - Extremely urgent situations                                               │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  ID: fa568361-7d53-4f8f-9532-b0353bd34f33                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Dear Employee,                                                              │
# │                                                                              │
# │  Thank you for your inquiry regarding your remaining casual leave balance    │
# │  for the current year. According to our Casual Leave Policy, casual leave    │
# │  entitlements are assigned annually and may vary based on leaves already     │
# │  taken. To provide you with an accurate update on your remaining casual      │
# │  leave days, we kindly ask that you share your employee ID or full name so   │
# │  we can access your leave records in our system.                             │
# │                                                                              │
# │  Alternatively, you may also check your available casual leave balance       │
# │  directly through the company’s self-service HR portal, if you have access.  │
# │  This portal allows you to securely view your updated leave balances at any  │
# │  time.                                                                       │
# │                                                                              │
# │  Please provide the requested details or log in to the HR portal to          │
# │  proceed. If you need any assistance with accessing the portal, feel free    │
# │  to let us know.                                                             │
# │                                                                              │
# │  Best regards,                                                               │
# │  [Your HR Team]                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# ...
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  ID: 5ebfcc6d-5a11-4534-9dcc-e98b58cacb31                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Thank you for your inquiry regarding eligibility for maternity leave        │
# │  before completing your probation period.                                    │
# │                                                                              │
# │  According to our company’s Maternity Leave Policy in conjunction with the   │
# │  Probation Period Policy, eligibility for maternity leave during probation   │
# │  depends on both local labor laws and company-specific guidelines. While     │
# │  statutory maternity leave rights often cannot be denied based on probation  │
# │  status, certain benefits such as paid leave may be subject to conditions    │
# │  or prorated during this time.                                               │
# │                                                                              │
# │  To proceed, please review the maternity leave and probation policies        │
# │  available on the company intranet or employee handbook. Additionally, we    │
# │  recommend contacting the HR department directly with the following          │
# │  information:                                                                │
# │                                                                              │
# │  - Your current probation status                                             │
# │  - The intended start date for your maternity leave                          │
# │                                                                              │
# │  This information will allow HR to verify your eligibility, clarify any      │
# │  benefits applicable during probation, and guide you through the formal      │
# │  application process if appropriate.                                         │
# │                                                                              │
# │  If you have further questions or need assistance, please feel free to       │
# │  reach out to HR, who will be happy to support you.                          │
# │                                                                              │
# │  We appreciate your proactive approach and wish you all the best.            │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 0f51a999-9142-4699-9b17-d5c832107b24                                    │
# │  Final Output: Thank you for your inquiry regarding eligibility for          │
# │  maternity leave before completing your probation period.                    │
# │                                                                              │
# │  According to our company’s Maternity Leave Policy in conjunction with the   │
# │  Probation Period Policy, eligibility for maternity leave during probation   │
# │  depends on both local labor laws and company-specific guidelines. While     │
# │  statutory maternity leave rights often cannot be denied based on probation  │
# │  status, certain benefits such as paid leave may be subject to conditions    │
# │  or prorated during this time.                                               │
# │                                                                              │
# │  To proceed, please review the maternity leave and probation policies        │
# │  available on the company intranet or employee handbook. Additionally, we    │
# │  recommend contacting the HR department directly with the following          │
# │  information:                                                                │
# │                                                                              │
# │  - Your current probation status                                             │
# │  - The intended start date for your maternity leave                          │
# │                                                                              │
# │  This information will allow HR to verify your eligibility, clarify any      │
# │  benefits applicable during probation, and guide you through the formal      │
# │  application process if appropriate.                                         │
# │                                                                              │
# │  If you have further questions or need assistance, please feel free to       │
# │  reach out to HR, who will be happy to support you.                          │
# │                                                                              │
# │  We appreciate your proactive approach and wish you all the best.            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ================================================================================
# Employee Query
# ================================================================================
# Can I apply for maternity leave before completing my probation?
#
#
# --------------------------------------------------------------------------------
#
#
# Response
# --------------------------------------------------------------------------------
# Thank you for your inquiry regarding eligibility for maternity leave before completing your probation period.
#
# According to our company’s Maternity Leave Policy in conjunction with the Probation Period Policy, eligibility for maternity leave during probation depends on both local labor laws and company-specific guidelines. While statutory maternity leave rights often cannot be denied based on probation status, certain benefits such as paid leave may be subject to conditions or prorated during this time.
#
# To proceed, please review the maternity leave and probation policies available on the company intranet or employee handbook. Additionally, we recommend contacting the HR department directly with the following information:
#
# - Your current probation status
# - The intended start date for your maternity leave
#
# This information will allow HR to verify your eligibility, clarify any benefits applicable during probation, and guide you through the formal application process if appropriate.
#
# If you have further questions or need assistance, please feel free to reach out to HR, who will be happy to support you.
#
# We appreciate your proactive approach and wish you all the best.
# ================================================================================
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):

# %%
import sys
# !{sys.executable} main.py
# Out:
# ================================================================================
# HR Employee Support System
# ================================================================================
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 2ded11c3-6d02-4cff-8b77-7b270c21c0fe                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category                                                              │
# │     - Leave                                                                  │
# │     - Payroll                                                                │
# │     - Benefits                                                               │
# │     - Internal Transfer                                                      │
# │     - Grievance                                                              │
# │     - General HR                                                             │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency                                                                  │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  4. Sensitivity                                                              │
# │     - Sensitive                                                              │
# │     - Not Sensitive                                                          │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  ID: 8a0ec3b3-0f50-45f0-9839-5de463f81c01                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Task:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category                                                              │
# │     - Leave                                                                  │
# │     - Payroll                                                                │
# │     - Benefits                                                               │
# │     - Internal Transfer                                                      │
# │     - Grievance                                                              │
# │     - General HR                                                             │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency                                                                  │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  4. Sensitivity                                                              │
# │     - Sensitive                                                              │
# │     - Not Sensitive                                                          │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Category: Leave                                                             │
# │  Intent: To inquire about the remaining casual leave balance for the year    │
# │  Urgency: Low                                                                │
# │  Sensitivity: Not Sensitive                                                  │
# │  Missing Information: None                                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category                                                              │
# │     - Leave                                                                  │
# │     - Payroll                                                                │
# │     - Benefits                                                               │
# │     - Internal Transfer                                                      │
# │     - Grievance                                                              │
# │     - General HR                                                             │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency                                                                  │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  4. Sensitivity                                                              │
# │     - Sensitive                                                              │
# │     - Not Sensitive                                                          │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category\n   - Leave\n   - Payroll\n   - Benefits\n   -  │
# │  Internal Transfer\n   - Grievance\n   - General HR\n\n2. Employee           │
# │  Intent\n\n3. Urgency\n   - Low\n   - Medium\n   - High\n\n4. Sensitivity\n  │
# │  - Sensitive\n   - Not Sensitive\n\n5. Any missing information               │
# │  required.\n\nReturn the output in the following                             │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('8a0ec3b3-0f50-45f0-9839-5de463f81c01') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │  - Leave                                                                     │
# │  - Payroll                                                                   │
# │  - Benefits                                                                  │
# │  - Internal Transfer                                                         │
# │  - Grievance                                                                 │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  ID: 64fbfe62-9397-4c00-96a5-00380d340a8f                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category\n   - Leave\n   - Payroll\n   - Benefits\n   -  │
# │  Internal Transfer\n   - Grievance\n   - General HR\n\n2. Employee           │
# │  Intent\n\n3. Urgency\n   - Low\n   - Medium\n   - High\n\n4. Sensitivity\n  │
# │  - Sensitive\n   - Not Sensitive\n\n5. Any missing information               │
# │  required.\n\nReturn the output in the following                             │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('8a0ec3b3-0f50-45f0-9839-5de463f81c01') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │  - Leave                                                                     │
# │  - Payroll                                                                   │
# │  - Benefits                                                                  │
# │  - Internal Transfer                                                         │
# │  - Grievance                                                                 │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Applicable Policy:                                                          │
# │  The Casual Leave Policy outlines the entitlements and procedures for        │
# │  employees regarding casual leave.                                           │
# │                                                                              │
# │  Eligibility:                                                                │
# │  All employees are eligible for casual leave as per the company's leave      │
# │  policy, which typically allocates a certain number of casual leave days     │
# │  per year based on the employee's length of service and employment status    │
# │  (full-time, part-time, etc.).                                               │
# │                                                                              │
# │  Explanation:                                                                │
# │  The employee is inquiring about their remaining casual leave balance for    │
# │  the current year. This is a standard inquiry that falls under the Leave     │
# │  category, and it is not urgent or sensitive. The employee is likely trying  │
# │  to plan their time off and needs to know how many casual leave days they    │
# │  have left to utilize.                                                       │
# │                                                                              │
# │  Recommended Next Step:                                                      │
# │  The employee should check their leave balance through the HR portal or      │
# │  contact the HR department directly for an accurate update on their          │
# │  remaining casual leave days. If the HR system is not accessible, HR can     │
# │  provide this information upon request.                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category\n   - Leave\n   - Payroll\n   - Benefits\n   -  │
# │  Internal Transfer\n   - Grievance\n   - General HR\n\n2. Employee           │
# │  Intent\n\n3. Urgency\n   - Low\n   - Medium\n   - High\n\n4. Sensitivity\n  │
# │  - Sensitive\n   - Not Sensitive\n\n5. Any missing information               │
# │  required.\n\nReturn the output in the following                             │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('8a0ec3b3-0f50-45f0-9839-5de463f81c01') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │  - Leave                                                                     │
# │  - Payroll                                                                   │
# │  - Benefits                                                                  │
# │  - Internal Transfer                                                         │
# │  - Grievance                                                                 │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │  - Harassment                                                                │
# │  - Bullying                                                                  │
# │  - Discrimination                                                            │
# │  - Workplace misconduct                                                      │
# │  - Data privacy                                                              │
# │  - Confidential matters                                                      │
# │  - Legal issues                                                              │
# │  - Threats                                                                   │
# │  - Violence                                                                  │
# │  - Extremely urgent situations                                               │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  ID: 2ad65f69-b3d9-48d1-97c8-fb63b695610f                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │  - Harassment                                                                │
# │  - Bullying                                                                  │
# │  - Discrimination                                                            │
# │  - Workplace misconduct                                                      │
# │  - Data privacy                                                              │
# │  - Confidential matters                                                      │
# │  - Legal issues                                                              │
# │  - Threats                                                                   │
# │  - Violence                                                                  │
# │  - Extremely urgent situations                                               │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Escalation Required: No                                                     │
# │  Priority: Low                                                               │
# │  Reason: The inquiry is a standard request for information regarding the     │
# │  remaining casual leave balance, which is not urgent or sensitive. The       │
# │  employee can check their leave balance through the HR portal or contact HR  │
# │  directly for assistance.                                                    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │  - Harassment                                                                │
# │  - Bullying                                                                  │
# │  - Discrimination                                                            │
# │  - Workplace misconduct                                                      │
# │  - Data privacy                                                              │
# │  - Confidential matters                                                      │
# │  - Legal issues                                                              │
# │  - Threats                                                                   │
# │  - Violence                                                                  │
# │  - Extremely urgent situations                                               │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │     - Low                                                                    │
# │     - Medium                                                                 │
# │     - High                                                                   │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  ID: 271000f2-ee7f-4e0f-87aa-c4363fb24423                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Subject: Inquiry About Casual Leave Balance                                 │
# │                                                                              │
# │  Dear [Employee's Name],                                                     │
# │                                                                              │
# │  Thank you for reaching out regarding your remaining casual leave balance    │
# │  for the year. As per our Casual Leave Policy, all employees are entitled    │
# │  to a certain number of casual leave days based on their length of service   │
# │  and employment status.                                                      │
# │                                                                              │
# │  To check your current casual leave balance, I recommend logging into the    │
# │  HR portal, where you can view your leave details. If you encounter any      │
# │  issues accessing the portal or need further assistance, please feel free    │
# │  to contact the HR department directly, and we will be happy to help you.    │
# │                                                                              │
# │  If you have any other questions or need further clarification, don’t        │
# │  hesitate to reach out.                                                      │
# │                                                                              │
# │  Best regards,                                                               │
# │                                                                              │
# │  [Your Name]                                                                 │
# │  [Your Position]                                                             │
# │  [Company Name]                                                              │
# │  [Contact Information]                                                       │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# ...
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  ID: 36b17437-ac2b-4287-acdd-3298aff8c9b9                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Subject: Acknowledgment of Your Concern                                     │
# │                                                                              │
# │  Dear [Employee's Name],                                                     │
# │                                                                              │
# │  Thank you for bringing your concerns to our attention. I want to            │
# │  acknowledge the seriousness of the situation you have described regarding   │
# │  the inappropriate behavior from your manager. It is important to us that    │
# │  all employees feel safe and respected in the workplace.                     │
# │                                                                              │
# │  Given the nature of your report, I have escalated this matter to the HR     │
# │  team for further investigation. They will handle your case with the utmost  │
# │  confidentiality and care, ensuring that your concerns are addressed         │
# │  appropriately.                                                              │
# │                                                                              │
# │  Please know that you are not alone in this process, and HR will provide     │
# │  you with the necessary support and resources as they move forward. If you   │
# │  have any additional details or information that you believe would be        │
# │  helpful, please feel free to share that with HR directly.                   │
# │                                                                              │
# │  Thank you for your courage in speaking up about this issue. Your            │
# │  well-being is our priority, and we are committed to maintaining a           │
# │  respectful and supportive work environment.                                 │
# │                                                                              │
# │  Best regards,                                                               │
# │                                                                              │
# │  [Your Name]                                                                 │
# │  [Your Position]                                                             │
# │  [Your Contact Information]                                                  │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 6dde1a2e-1202-4c4a-b8cf-25f597aa4ee3                                    │
# │  Final Output: Subject: Acknowledgment of Your Concern                       │
# │                                                                              │
# │  Dear [Employee's Name],                                                     │
# │                                                                              │
# │  Thank you for bringing your concerns to our attention. I want to            │
# │  acknowledge the seriousness of the situation you have described regarding   │
# │  the inappropriate behavior from your manager. It is important to us that    │
# │  all employees feel safe and respected in the workplace.                     │
# │                                                                              │
# │  Given the nature of your report, I have escalated this matter to the HR     │
# │  team for further investigation. They will handle your case with the utmost  │
# │  confidentiality and care, ensuring that your concerns are addressed         │
# │  appropriately.                                                              │
# │                                                                              │
# │  Please know that you are not alone in this process, and HR will provide     │
# │  you with the necessary support and resources as they move forward. If you   │
# │  have any additional details or information that you believe would be        │
# │  helpful, please feel free to share that with HR directly.                   │
# │                                                                              │
# │  Thank you for your courage in speaking up about this issue. Your            │
# │  well-being is our priority, and we are committed to maintaining a           │
# │  respectful and supportive work environment.                                 │
# │                                                                              │
# │  Best regards,                                                               │
# │                                                                              │
# │  [Your Name]                                                                 │
# │  [Your Position]                                                             │
# │  [Your Contact Information]                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ================================================================================
# Employee Query
# ================================================================================
# My manager repeatedly insults me during meetings and I want to report this.
#
# --------------------------------------------------------------------------------
#
# Response
# --------------------------------------------------------------------------------
# Subject: Acknowledgment of Your Concern
#
# Dear [Employee's Name],
#
# Thank you for bringing your concerns to our attention. I want to acknowledge the seriousness of the situation you have described regarding the inappropriate behavior from your manager. It is important to us that all employees feel safe and respected in the workplace.
#
# Given the nature of your report, I have escalated this matter to the HR team for further investigation. They will handle your case with the utmost confidentiality and care, ensuring that your concerns are addressed appropriately.
#
# Please know that you are not alone in this process, and HR will provide you with the necessary support and resources as they move forward. If you have any additional details or information that you believe would be helpful, please feel free to share that with HR directly.
#
# Thank you for your courage in speaking up about this issue. Your well-being is our priority, and we are committed to maintaining a respectful and supportive work environment.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# [Your Contact Information]
# ================================================================================
# ╭─────────────────────────────── Tracing Status ───────────────────────────────╮
# │                                                                              │
# │  Info: Tracing is disabled.                                                  │
# │                                                                              │
# │  To enable tracing, do any one of these:                                     │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print("Model:", os.getenv("HR_AGENT_MODEL"))
print("Temperature:", os.getenv("TEMPERATURE"))
print("API Key:", os.getenv("OPENAI_API_KEY"))
print("Base URL:", os.getenv("BASE_URL"))
# Out:
# Model: gpt-4o-mini
# Temperature: 0
# API Key: voc-45885050117535049616326a1123f9d9a513.30337409
# Base URL: https://openai.vocareum.com/v1

# %%
import sys
# !{sys.executable} main.py
# Out:
# ================================================================================
# HR Employee Support System
# ================================================================================
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 67ced190-225a-41f1-861e-7ffc83cba768                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category:                                                             │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency:                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  4. Sensitivity:                                                             │
# │                                                                              │
# │      1. Sensitive                                                            │
# │      2. Not Sensitive                                                        │
# │                                                                              │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  ID: fc550fe9-87a3-4f51-a9bf-761501f352d9                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Task:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category:                                                             │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency:                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  4. Sensitivity:                                                             │
# │                                                                              │
# │      1. Sensitive                                                            │
# │      2. Not Sensitive                                                        │
# │                                                                              │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Category: Leave                                                             │
# │  Intent: To inquire about the remaining casual leave balance for the year    │
# │  Urgency: Low                                                                │
# │  Sensitivity: Not Sensitive                                                  │
# │  Missing Information: None                                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category:                                                             │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency:                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  4. Sensitivity:                                                             │
# │                                                                              │
# │      1. Sensitive                                                            │
# │      2. Not Sensitive                                                        │
# │                                                                              │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('fc550fe9-87a3-4f51-a9bf-761501f352d9') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  ID: b7779f80-b0c9-4f53-8dd1-d6bac9835a40                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('fc550fe9-87a3-4f51-a9bf-761501f352d9') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Applicable Policy: "Casual Leave": "Employees are entitled to 12 casual     │
# │  leave days per year."                                                       │
# │                                                                              │
# │  Eligibility: All employees are eligible for casual leave as per the         │
# │  policy.                                                                     │
# │                                                                              │
# │  Explanation: The employee is inquiring about the remaining casual leave     │
# │  balance for the year. According to the HR policy, employees are entitled    │
# │  to 12 casual leave days annually. The inquiry does not indicate any         │
# │  urgency or sensitivity, and no additional information is required to        │
# │  address the question.                                                       │
# │                                                                              │
# │  Recommended Next Step: The employee should check their leave balance        │
# │  through the HR portal or contact the HR department directly for an updated  │
# │  count of their remaining casual leave days for the year.                    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('fc550fe9-87a3-4f51-a9bf-761501f352d9') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying",                                                           │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  ID: 518ff1d5-95c1-45d8-b254-b905591081ee                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying",                                                           │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Escalation Required: No                                                     │
# │  Priority: Low                                                               │
# │  Reason: The inquiry is about the remaining casual leave balance for the     │
# │  year, which is a standard HR matter that does not involve any sensitive     │
# │  issues such as harassment, discrimination, or legal concerns. The employee  │
# │  can check their leave balance through the HR portal or contact the HR       │
# │  department directly.                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying",                                                           │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# ...
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  ID: 13147f2d-fd8e-4052-91be-dbf08bf2f0e2                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Subject: Acknowledgment of Your Concern                                     │
# │                                                                              │
# │  Dear [Employee's Name],                                                     │
# │                                                                              │
# │  Thank you for bringing your concerns to our attention. I want to            │
# │  acknowledge the seriousness of the situation you have described regarding   │
# │  the inappropriate behavior from your manager. It is important to us that    │
# │  all employees feel safe and respected in the workplace.                     │
# │                                                                              │
# │  Given the nature of your report, which falls under our Harassment policy,   │
# │  I want to inform you that I have escalated your case to the HR team for     │
# │  further investigation. They will handle this matter with the utmost         │
# │  confidentiality and care.                                                   │
# │                                                                              │
# │  Please know that your concerns are taken seriously, and the HR team will    │
# │  reach out to you shortly to discuss the next steps. In the meantime, if     │
# │  you have any additional information, such as specific incidents, any        │
# │  witnesses, or whether you have previously addressed this issue with your    │
# │  manager or HR, please feel free to share that with them.                    │
# │                                                                              │
# │  Thank you for your courage in speaking up. We are here to support you.      │
# │                                                                              │
# │  Best regards,                                                               │
# │                                                                              │
# │  [Your Name]                                                                 │
# │  [Your Position]                                                             │
# │  [Your Contact Information]                                                  │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Generate the final employee response.                                       │
# │                                                                              │
# │  Use:                                                                        │
# │                                                                              │
# │  • Classification Output                                                     │
# │  • Policy Reasoning Output                                                   │
# │  • Escalation Decision                                                       │
# │                                                                              │
# │  Rules:                                                                      │
# │                                                                              │
# │  If escalation is NOT required:                                              │
# │                                                                              │
# │  - Answer professionally                                                     │
# │  - Mention applicable policy                                                 │
# │  - Explain next steps                                                        │
# │                                                                              │
# │  If escalation IS required:                                                  │
# │                                                                              │
# │  - Do NOT attempt to resolve the issue.                                      │
# │  - Acknowledge the concern.                                                  │
# │  - Inform the employee that the case has been forwarded                      │
# │    to the HR team.                                                           │
# │  - Maintain confidentiality.                                                 │
# │  - Be empathetic.                                                            │
# │                                                                              │
# │  Agent: Response Generation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 51b4c488-fb97-47c0-80bb-3b2e3f783d22                                    │
# │  Final Output: Subject: Acknowledgment of Your Concern                       │
# │                                                                              │
# │  Dear [Employee's Name],                                                     │
# │                                                                              │
# │  Thank you for bringing your concerns to our attention. I want to            │
# │  acknowledge the seriousness of the situation you have described regarding   │
# │  the inappropriate behavior from your manager. It is important to us that    │
# │  all employees feel safe and respected in the workplace.                     │
# │                                                                              │
# │  Given the nature of your report, which falls under our Harassment policy,   │
# │  I want to inform you that I have escalated your case to the HR team for     │
# │  further investigation. They will handle this matter with the utmost         │
# │  confidentiality and care.                                                   │
# │                                                                              │
# │  Please know that your concerns are taken seriously, and the HR team will    │
# │  reach out to you shortly to discuss the next steps. In the meantime, if     │
# │  you have any additional information, such as specific incidents, any        │
# │  witnesses, or whether you have previously addressed this issue with your    │
# │  manager or HR, please feel free to share that with them.                    │
# │                                                                              │
# │  Thank you for your courage in speaking up. We are here to support you.      │
# │                                                                              │
# │  Best regards,                                                               │
# │                                                                              │
# │  [Your Name]                                                                 │
# │  [Your Position]                                                             │
# │  [Your Contact Information]                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ================================================================================
#
# Employee Query
# ================================================================================
# My manager repeatedly insults me during meetings and I want to report this.
#
# --------------------------------------------------------------------------------
# Response
# --------------------------------------------------------------------------------
# Subject: Acknowledgment of Your Concern
#
# Dear [Employee's Name],
#
# Thank you for bringing your concerns to our attention. I want to acknowledge the seriousness of the situation you have described regarding the inappropriate behavior from your manager. It is important to us that all employees feel safe and respected in the workplace.
#
# Given the nature of your report, which falls under our Harassment policy, I want to inform you that I have escalated your case to the HR team for further investigation. They will handle this matter with the utmost confidentiality and care.
#
# Please know that your concerns are taken seriously, and the HR team will reach out to you shortly to discuss the next steps. In the meantime, if you have any additional information, such as specific incidents, any witnesses, or whether you have previously addressed this issue with your manager or HR, please feel free to share that with them.
#
# Thank you for your courage in speaking up. We are here to support you.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# [Your Contact Information]
# ================================================================================
# ╭─────────────────────────────── Tracing Status ───────────────────────────────╮
# │                                                                              │
# │  Info: Tracing is disabled.                                                  │
# │                                                                              │
# │  To enable tracing, do any one of these:                                     │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
import sys 
# !{sys.executable} main.py
# Out:
# ================================================================================
# HR Employee Support System
# ================================================================================
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: f9bd08d6-28c2-47a1-a572-4b9f051b2f6b                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category:                                                             │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency:                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  4. Sensitivity:                                                             │
# │                                                                              │
# │      1. Sensitive                                                            │
# │      2. Not Sensitive                                                        │
# │                                                                              │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  ID: 201f950c-1abe-4b15-9607-cc343f038b25                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Task:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category:                                                             │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency:                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  4. Sensitivity:                                                             │
# │                                                                              │
# │      1. Sensitive                                                            │
# │      2. Not Sensitive                                                        │
# │                                                                              │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Category: Leave                                                             │
# │  Intent: To inquire about the remaining casual leave balance for the year    │
# │  Urgency: Low                                                                │
# │  Sensitivity: Not Sensitive                                                  │
# │  Missing Information: None                                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  You are given the following employee query:                                 │
# │                                                                              │
# │  "How many casual leaves do I have remaining this year?"                     │
# │                                                                              │
# │  Analyze the query and identify:                                             │
# │                                                                              │
# │  1. HR Category:                                                             │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  2. Employee Intent                                                          │
# │                                                                              │
# │  3. Urgency:                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  4. Sensitivity:                                                             │
# │                                                                              │
# │      1. Sensitive                                                            │
# │      2. Not Sensitive                                                        │
# │                                                                              │
# │                                                                              │
# │  5. Any missing information required.                                        │
# │                                                                              │
# │  Return the output in the following format:                                  │
# │                                                                              │
# │  Category:                                                                   │
# │  Intent:                                                                     │
# │  Urgency:                                                                    │
# │  Sensitivity:                                                                │
# │  Missing Information:                                                        │
# │                                                                              │
# │  Agent: Query Classification Agent                                           │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('201f950c-1abe-4b15-9607-cc343f038b25') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  ID: c8fd4dd3-25dc-4476-9e5c-7da35978d0c5                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('201f950c-1abe-4b15-9607-cc343f038b25') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Applicable Policy: Casual Leave                                             │
# │  Eligibility: All employees are entitled to 12 casual leave days per year.   │
# │  Explanation: The employee is inquiring about the remaining casual leave     │
# │  balance for the year. According to the HR policy, employees are entitled    │
# │  to a total of 12 casual leave days annually. The employee's remaining       │
# │  balance can be calculated based on the number of casual leave days taken    │
# │  so far this year.                                                           │
# │  Recommended Next Step: The employee should check their leave records or     │
# │  contact HR to obtain the current balance of their casual leave days         │
# │  remaining for the year.                                                     │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"How many     │
# │  casual leaves do I have remaining this year?"\n\nAnalyze the query and      │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('201f950c-1abe-4b15-9607-cc343f038b25') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying,                                                            │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  ID: 427eb6a0-212f-4fd1-b861-60650ea19897                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying,                                                            │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# [Finalize] todos_count=0, todos_with_results=0
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Escalation Required: No                                                     │
# │  Priority: Low                                                               │
# │  Reason: The inquiry pertains to a standard request for information about    │
# │  casual leave balance, which does not involve any sensitive issues or        │
# │  require HR intervention. The employee can check their leave records or      │
# │  contact HR directly for this information.                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying,                                                            │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# ...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Applicable Policy: Internal Transfer Policy (not explicitly listed but      │
# │  inferred from the context of the query)                                     │
# │                                                                              │
# │  Eligibility: Employees must complete at least 12 months in their current    │
# │  role.                                                                       │
# │                                                                              │
# │  Explanation: The employee is inquiring about the process to transfer to     │
# │  another department, which falls under the category of Internal Transfer.    │
# │  According to common HR practices, employees typically need to meet certain  │
# │  eligibility criteria, such as having completed a minimum duration in their  │
# │  current position, which in this case is 12 months.                          │
# │                                                                              │
# │  Recommended Next Step: The employee should confirm their eligibility by     │
# │  checking if they have completed at least 12 months in their current role.   │
# │  If eligible, they should reach out to their current manager or HR           │
# │  department to initiate the transfer process and obtain the necessary forms  │
# │  or guidelines for the transfer.                                             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name:                                                                       │
# │  Based on the classification below:                                          │
# │                                                                              │
# │  used_tools=0 tools_errors=0 delegations=0 name=None prompt_context=None     │
# │  description='\nYou are given the following employee query:\n\n"What is the  │
# │  process to transfer to another department?"\n\nAnalyze the query and        │
# │  identify:\n\n1. HR Category:\n   \n    1. Leave,\n    2. Payroll,\n    3.   │
# │  Benefits,\n    4. Internal Transfer,\n    5. Grievance,\n    6. General     │
# │  HR\n\n\n2. Employee Intent\n\n3. Urgency:\n   \n    1. Low\n    2.          │
# │  Medium\n    3. High\n\n\n4. Sensitivity:\n   \n    1. Sensitive\n    2.     │
# │  Not Sensitive\n\n\n5. Any missing information required.\n\nReturn the       │
# │  output in the following                                                     │
# │  format:\n\nCategory:\nIntent:\nUrgency:\nSensitivity:\nMissing              │
# │  Information:\n            ' expected_output='\nA structured summary         │
# │  containing:\n- Category\n- Intent\n- Urgency\n- Sensitivity\n- Missing      │
# │  Information\n            ' config=None callback=None                        │
# │  agent=Agent(role=Query Classification Agent, goal=Classify employee         │
# │  queries into HR categories., backstory=Expert at identifying employee       │
# │  intent, urgency and sensitivity.) context=NOT_SPECIFIED                     │
# │  async_execution=False output_json=None output_pydantic=None                 │
# │  response_model=None output_file=None create_directory=True output=None      │
# │  tools=[] input_files={}                                                     │
# │  security_config=SecurityConfig(fingerprint=Fingerprint(metadata={}))        │
# │  id=UUID('b3fb8b91-1610-4fc5-adeb-fc8a6b3fbcb3') human_input=False           │
# │  markdown=False converter_cls=None processed_by_agents=set() guardrail=None  │
# │  guardrails=None max_retries=None guardrail_max_retries=3 retry_count=0      │
# │  start_time=None end_time=None allow_crewai_trigger_context=None             │
# │  checkpoint_original_description=None                                        │
# │  checkpoint_original_expected_output=None                                    │
# │                                                                              │
# │  Use ONLY the following HR policies.                                         │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │          "Annual Leave": "Employees are entitled to 18 days of annual leave  │
# │  per year.",                                                                 │
# │          "Casual Leave": "Employees are entitled to 12 casual leave days     │
# │  per year.",                                                                 │
# │          "Sick Leave": "Employees are entitled to 10 sick leave days per     │
# │  year."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Salary Correction": "Salary discrepancies must be reported within  │
# │  7 working days.",                                                           │
# │          "Tax Queries": "Tax-related questions are handled by the Payroll    │
# │  Team."                                                                      │
# │                                                                              │
# │                                                                              │
# │          "Medical Insurance": "Employees become eligible after successful    │
# │  completion of probation."                                                   │
# │                                                                              │
# │                                                                              │
# │          "Eligibility": "Employees must complete at least 12 months in       │
# │  their current role."                                                        │
# │                                                                              │
# │                                                                              │
# │          "Harassment": "Harassment complaints must be escalated immediately  │
# │  to HR."                                                                     │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# │  Determine the appropriate HR policy that applies.                           │
# │                                                                              │
# │  Use common HR practices for:                                                │
# │                                                                              │
# │                                                                              │
# │      1. Leave,                                                               │
# │      2. Payroll,                                                             │
# │      3. Benefits,                                                            │
# │      4. Internal Transfer,                                                   │
# │      5. Grievance,                                                           │
# │      6. General HR                                                           │
# │                                                                              │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Applicable Policy                                                        │
# │  2. Employee Eligibility (if applicable)                                     │
# │  3. Explanation                                                              │
# │  4. Recommended Next Step                                                    │
# │                                                                              │
# │  Agent: HR Policy Reasoning Agent                                            │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying,                                                            │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │  ID: 2fc719fa-4fe6-4081-92af-4b4d3e826911                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Human HR Escalation Agent                                            │
# │                                                                              │
# │  Task:                                                                       │
# │  Review the employee case and determine whether it requires                  │
# │  Human HR intervention.                                                      │
# │                                                                              │
# │  Escalate if the query involves:                                             │
# │                                                                              │
# │                                                                              │
# │      1. Harassment,                                                          │
# │      2. Bullying,                                                            │
# │      3. Discrimination,                                                      │
# │      4. Data Privacy,                                                        │
# │      5. Legal Issues,                                                        │
# │      6. Threats,                                                             │
# │      7. Abuse,                                                               │
# │      8. Sexual harassment,                                                   │
# │      9. Violence,                                                            │
# │      10. Confidential matters,                                               │
# │      11. Workplace misconduct,                                               │
# │      12. Extremely urgent situations                                         │
# │                                                                              │
# │                                                                              │
# │  Otherwise, recommend automated resolution.                                  │
# │                                                                              │
# │  Provide:                                                                    │
# │                                                                              │
# │  1. Escalation Required (Yes/No)                                             │
# │                                                                              │
# │  2. Priority                                                                 │
# │                                                                              │
# │      1. Low                                                                  │
# │      2. Medium                                                               │
# │      3. High                                                                 │
# │                                                                              │
# │                                                                              │
# │  3. Reason                                                                   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
